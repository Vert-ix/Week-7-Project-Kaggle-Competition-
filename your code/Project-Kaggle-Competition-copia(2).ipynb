# %%
import pandas as pd

import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
salaries = pd.read_csv('../data/salaries_data.csv')
salaries.head()
# Out:
#    work_year experience_level employment_type        job_title  salary_in_usd  \
# 0       2022               SE              FT    Data Engineer         140250
# 1       2022               SE              FT    Data Engineer         135000
# 2       2021               MI              FT  BI Data Analyst         100000
# 3       2021               MI              CT      ML Engineer         270000
# 4       2021               MI              FT    Data Engineer          26005
#
#   employee_residence  remote_ratio company_location company_size
# 0                 US           100               US            M
# 1                 US           100               US            M
# 2                 US           100               US            M
# 3                 US           100               US            L
# 4                 RO             0               US            L

# %%
salaries.shape
# Out:
# (500, 9)

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           500 non-null    int64
#  1   experience_level    500 non-null    object
#  2   employment_type     500 non-null    object
#  3   job_title           500 non-null    object
#  4   salary_in_usd       500 non-null    int64
#  5   employee_residence  500 non-null    object
#  6   remote_ratio        500 non-null    int64
#  7   company_location    500 non-null    object
#  8   company_size        500 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 35.3+ KB

# %%
test = pd.read_csv('../data/test.csv')
test.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               SE              FT  Machine Learning Scientist
# 1       2020               MI              FT           Lead Data Analyst
# 2       2020               MI              FT                Data Analyst
# 3       2020               MI              FT   Machine Learning Engineer
# 4       2020               MI              FT        Product Data Analyst
#
#   employee_residence  remote_ratio company_location company_size
# 0                 JP             0               JP            S
# 1                 US           100               US            L
# 2                 US           100               US            L
# 3                 CN             0               CN            M
# 4                 IN           100               IN            L

# %%
# Unimos los archivos csv.

df = pd.concat([salaries, test], axis = 0)

# %%
df.head()
# Out:
#    work_year experience_level employment_type        job_title  salary_in_usd  \
# 0       2022               SE              FT    Data Engineer       140250.0
# 1       2022               SE              FT    Data Engineer       135000.0
# 2       2021               MI              FT  BI Data Analyst       100000.0
# 3       2021               MI              CT      ML Engineer       270000.0
# 4       2021               MI              FT    Data Engineer        26005.0
#
#   employee_residence  remote_ratio company_location company_size
# 0                 US           100               US            M
# 1                 US           100               US            M
# 2                 US           100               US            M
# 3                 US           100               US            L
# 4                 RO             0               US            L

# %%
company_size={'S': 0, 'M': 1, 'L': 2}  

def cambio_size(x):   
    return size[x]    

df.company_size=df.company_size.apply(lambda x: company_size[x])

df.head()
# Out:
#    work_year experience_level employment_type        job_title  salary_in_usd  \
# 0       2022               SE              FT    Data Engineer       140250.0
# 1       2022               SE              FT    Data Engineer       135000.0
# 2       2021               MI              FT  BI Data Analyst       100000.0
# 3       2021               MI              CT      ML Engineer       270000.0
# 4       2021               MI              FT    Data Engineer        26005.0
#
#   employee_residence  remote_ratio company_location  company_size
# 0                 US           100               US             1
# 1                 US           100               US             1
# 2                 US           100               US             1
# 3                 US           100               US             2
# 4                 RO             0               US             2

# %%
df=pd.get_dummies(df, columns=['employment_type'])   

df.head()
# Out:
#    work_year experience_level        job_title  salary_in_usd  \
# 0       2022               SE    Data Engineer       140250.0
# 1       2022               SE    Data Engineer       135000.0
# 2       2021               MI  BI Data Analyst       100000.0
# 3       2021               MI      ML Engineer       270000.0
# 4       2021               MI    Data Engineer        26005.0
#
#   employee_residence  remote_ratio company_location  company_size  \
# 0                 US           100               US             1
# 1                 US           100               US             1
# 2                 US           100               US             1
# 3                 US           100               US             2
# 4                 RO             0               US             2
#
#    employment_type_CT  employment_type_FL  employment_type_FT  \
# 0                   0                   0                   1
# 1                   0                   0                   1
# ...

# %%
df=pd.get_dummies(df, columns=['experience_level'])   

df.head()
# Out:
#    work_year        job_title  salary_in_usd employee_residence  remote_ratio  \
# 0       2022    Data Engineer       140250.0                 US           100
# 1       2022    Data Engineer       135000.0                 US           100
# 2       2021  BI Data Analyst       100000.0                 US           100
# 3       2021      ML Engineer       270000.0                 US           100
# 4       2021    Data Engineer        26005.0                 RO             0
#
#   company_location  company_size  employment_type_CT  employment_type_FL  \
# 0               US             1                   0                   0
# 1               US             1                   0                   0
# 2               US             1                   0                   0
# 3               US             2                   1                   0
# 4               US             2                   0                   0
#
# ...

# %%
company_location = {'US':53229, 'FR':39971, 'GR':18831, 'LU':67263, 'SI':22485, 'DE':52556, 'IN':40219, 'GB':51161, 'PK':17500, 'MD':1000, 'JP':39628,
       'CA':49937, 'AS':31492, 'IE':50636, 'AE':150000, 'MX':136170, 'VN':3281, 'BE':52248, 'KE':13471, 'ES':26832, 'CH':87401, 'CL':12009,
       'CN':1500, 'DK':61532, 'TR':8294, 'NZ':39511, 'PL':14039, 'UA':3887, 'AU':59250, 'NG':1891, 'EE':18329, 'CZ':16978, 'AT':50460,
       'BR':1212, 'DZ':3447, 'IR':3671, 'NL':55339, 'HU':15063, 'PT':20602, 'HN':5907, 'MT':23950, 'RO':12682, 'SG':51093, 'IT':34032,
       'HR':14258, 'IQ':6827, 'IL':46071, 'RU':14450, 'CO':4348, 'MY':10006}

def cambio_paises(x):   
    return paises[x]    

df.company_location=df.company_location.apply(lambda x: company_location[x])

df.head()
# Out:
#    work_year        job_title  salary_in_usd employee_residence  remote_ratio  \
# 0       2022    Data Engineer       140250.0                 US           100
# 1       2022    Data Engineer       135000.0                 US           100
# 2       2021  BI Data Analyst       100000.0                 US           100
# 3       2021      ML Engineer       270000.0                 US           100
# 4       2021    Data Engineer        26005.0                 RO             0
#
#    company_location  company_size  employment_type_CT  employment_type_FL  \
# 0             53229             1                   0                   0
# 1             53229             1                   0                   0
# 2             53229             1                   0                   0
# 3             53229             2                   1                   0
# 4             53229             2                   0                   0
#
# ...

# %%
df.company_location.unique()
# Out:
# array([ 53229,  39971,  18831,  67263,  22485,  52556,  40219,  51161,
#         17500,   1000,  39628,  49937,  31492,  50636, 150000, 136170,
#          3281,  52248,  13471,  26832,  87401,  12009,   1500,  61532,
#          8294,  39511,  14039,   3887,  59250,   1891,  18329,  16978,
#         50460,   1212,   3447,   3671,  55339,  15063,  20602,   5907,
#         23950,  12682,  51093,  34032,  14258,   6827,  46071,  14450,
#          4348,  10006], dtype=int64)

# %%
df=pd.get_dummies(df, columns=['employee_residence'])   
df.head()
# Out:
#    work_year        job_title  salary_in_usd  remote_ratio  company_location  \
# 0       2022    Data Engineer       140250.0           100             53229
# 1       2022    Data Engineer       135000.0           100             53229
# 2       2021  BI Data Analyst       100000.0           100             53229
# 3       2021      ML Engineer       270000.0           100             53229
# 4       2021    Data Engineer        26005.0             0             53229
#
#    company_size  employment_type_CT  employment_type_FL  employment_type_FT  \
# 0             1                   0                   0                   1
# 1             1                   0                   0                   1
# 2             1                   0                   0                   1
# 3             2                   1                   0                   0
# 4             2                   0                   0                   1
#
# ...

# %%
remote_ratio={0: 0, 50: 1, 100: 2}  

def cambio_ratio(x):   
    return remote_ratio[x]    

df.remote_ratio=df.remote_ratio.apply(lambda x: remote_ratio[x])

df.head()
# Out:
#    work_year        job_title  salary_in_usd  remote_ratio  company_location  \
# 0       2022    Data Engineer       140250.0             2             53229
# 1       2022    Data Engineer       135000.0             2             53229
# 2       2021  BI Data Analyst       100000.0             2             53229
# 3       2021      ML Engineer       270000.0             2             53229
# 4       2021    Data Engineer        26005.0             0             53229
#
#    company_size  employment_type_CT  employment_type_FL  employment_type_FT  \
# 0             1                   0                   0                   1
# 1             1                   0                   0                   1
# 2             1                   0                   0                   1
# 3             2                   1                   0                   0
# 4             2                   0                   0                   1
#
# ...

# %%
df.shape
# Out:
# (607, 71)

# %%
df.job_title.unique()
# Out:
# array(['Data Engineer', 'BI Data Analyst', 'ML Engineer',
#        'Machine Learning Scientist', 'Data Scientist', 'Data Analyst',
#        'Machine Learning Engineer', 'Principal Data Scientist',
#        'Data Engineering Manager', 'Data Analytics Manager',
#        'Big Data Engineer', 'Research Scientist',
#        'Machine Learning Developer', 'Computer Vision Engineer',
#        'AI Scientist', 'Machine Learning Manager', 'Lead Data Scientist',
#        'Director of Data Science', '3D Computer Vision Researcher',
#        'Data Specialist', 'Applied Data Scientist',
#        'Data Science Engineer', 'Head of Data', 'Analytics Engineer',
#        'ETL Developer', 'Marketing Data Analyst', 'Data Architect',
#        'Data Science Consultant', 'Principal Data Analyst',
#        'Head of Data Science', 'Lead Data Engineer',
#        'Data Science Manager', 'Applied Machine Learning Scientist',
#        'Lead Data Analyst', 'Cloud Data Engineer',
# ...

# %%
df.job_title.value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Director of Data Science                      7
# AI Scientist                                  7
# Data Analytics Manager                        7
# Principal Data Scientist                      7
# Data Science Consultant                       7
# Computer Vision Engineer                      6
# Lead Data Engineer                            6
# BI Data Analyst                               6
# ML Engineer                                   6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
df.job_title = ["Data Engineer" if "Engineer" in word else word for word in df.job_title]
df.job_title = ["Data Architect" if "Architect" in word else word for word in df.job_title]
df.job_title = ["Data Analyst" if "Analyst" in word or "Data Analytics Lead" in word else word for word in df.job_title]
df.job_title = ["Computer Vision" if "ision" in word else word for word in df.job_title]
df.job_title = ["Data Scientist" if "Data Scientist" in word or "Data Science" in word else word for word in df.job_title]
df.job_title = ["Machine Learning Engineer" if "Machine Learning Engineer" in word or "Machine Learning Developer"  in word or "Machine Learning Manager" in word or "Machine Learning Engineer"  in word else word for word in df.job_title]
df.job_title = ["Machine Learning Scientist" if "Machine Learning Scientist" in word else word for word in df.job_title]
df.job_title = ["Finance Data Analyst" if "Finance" in word or "Financial" in word else word for word in df.job_title]
df.job_title = ["AI Scientist" if "AI Scientist" in word or "AI" in word else word for word in df.job_title]

top13 = list(df.job_title.value_counts().index[:12])



df.job_title.value_counts()
# Out:
# Data Engineer                 230
# Data Scientist                189
# Data Analyst                  120
# Research Scientist             16
# Machine Learning Scientist     12
# Data Architect                 12
# Data Analytics Manager          7
# AI Scientist                    7
# Head of Data                    5
# Machine Learning Engineer       4
# ETL Developer                   2
# Computer Vision                 1
# Data Specialist                 1
# Head of Machine Learning        1
# Name: job_title, dtype: int64

# %%
top13
# Out:
# ['Data Engineer',
#  'Data Scientist',
#  'Data Analyst',
#  'Research Scientist',
#  'Machine Learning Scientist',
#  'Data Architect',
#  'Data Analytics Manager',
#  'AI Scientist',
#  'Head of Data',
#  'Machine Learning Engineer',
#  'ETL Developer',
#  'Computer Vision']

# %%
job_title = [word if word in top13 else 'Other' for word in df.job_title]
np.unique(job_title)
# Out:
# array(['AI Scientist', 'Computer Vision', 'Data Analyst',
#        'Data Analytics Manager', 'Data Architect', 'Data Engineer',
#        'Data Scientist', 'ETL Developer', 'Head of Data',
#        'Machine Learning Engineer', 'Machine Learning Scientist', 'Other',
#        'Research Scientist'], dtype='<U26')

# %%
df.job_title = job_title

# %%
df.job_title.value_counts()
# Out:
# Data Engineer                 230
# Data Scientist                189
# Data Analyst                  120
# Research Scientist             16
# Machine Learning Scientist     12
# Data Architect                 12
# Data Analytics Manager          7
# AI Scientist                    7
# Head of Data                    5
# Machine Learning Engineer       4
# Other                           2
# ETL Developer                   2
# Computer Vision                 1
# Name: job_title, dtype: int64

# %%
df=pd.get_dummies(df, columns=['job_title'])   

df.head()
# Out:
#    work_year  salary_in_usd  remote_ratio  company_location  company_size  \
# 0       2022       140250.0             2             53229             1
# 1       2022       135000.0             2             53229             1
# 2       2021       100000.0             2             53229             1
# 3       2021       270000.0             2             53229             2
# 4       2021        26005.0             0             53229             2
#
#    employment_type_CT  employment_type_FL  employment_type_FT  \
# 0                   0                   0                   1
# 1                   0                   0                   1
# 2                   0                   0                   1
# 3                   1                   0                   0
# 4                   0                   0                   1
#
#    employment_type_PT  experience_level_EN  ...  \
# 0                   0                    0  ...
# ...

# %%
# label encoder
#from sklearn.preprocessing import LabelEncoder

#df.company_location=LabelEncoder().fit_transform(df.company_location)

#df.head(10)

# %%
# Borrar outliers

#outliers = list(df[df.salary_in_usd >= 60000].index)
#df.drop(outliers, axis=0, inplace=True)

# %%
salario_lim= df.iloc[:500,:]
salario_lim
# Out:
#      work_year  salary_in_usd  remote_ratio  company_location  company_size  \
# 0         2022       140250.0             2             53229             1
# 1         2022       135000.0             2             53229             1
# 2         2021       100000.0             2             53229             1
# 3         2021       270000.0             2             53229             2
# 4         2021        26005.0             0             53229             2
# ..         ...            ...           ...               ...           ...
# 495       2022       100000.0             2             53229             1
# 496       2021         5882.0             0             87401             2
# 497       2022        90700.0             2             49937             1
# 498       2021        82528.0             2             51161             2
# 499       2021        70000.0             2             53229             1
#
# ...

# %%
test_lim= df.iloc[500:,:].drop('salary_in_usd', axis=1)
test_lim
# Out:
#      work_year  remote_ratio  company_location  company_size  \
# 0         2020             0             39628             0
# 1         2020             2             53229             2
# 2         2020             2             53229             2
# 3         2020             0              1500             1
# 4         2020             2             40219             2
# ..         ...           ...               ...           ...
# 102       2022             2             53229             1
# 103       2022             2             53229             1
# 104       2022             2             53229             1
# 105       2022             0             49937             1
# 106       2022             0             53229             1
#
#      employment_type_CT  employment_type_FL  employment_type_FT  \
# 0                     0                   0                   1
# 1                     0                   0                   1
# ...

# %%
X = salario_lim.drop('salary_in_usd', axis = 1)
X
# Out:
#      work_year  remote_ratio  company_location  company_size  \
# 0         2022             2             53229             1
# 1         2022             2             53229             1
# 2         2021             2             53229             1
# 3         2021             2             53229             2
# 4         2021             0             53229             2
# ..         ...           ...               ...           ...
# 495       2022             2             53229             1
# 496       2021             0             87401             2
# 497       2022             2             49937             1
# 498       2021             2             51161             2
# 499       2021             2             53229             1
#
#      employment_type_CT  employment_type_FL  employment_type_FT  \
# 0                     0                   0                   1
# 1                     0                   0                   1
# ...

# %%
y = salario_lim.salary_in_usd
y.shape
# Out:
# (500,)

# %%
from sklearn.model_selection import train_test_split as tts 

X_train, X_test, y_train, y_test = tts(X, y, train_size=0.8, test_size=0.2, random_state=22)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((400, 82), (100, 82), (400,), (100,))

# %%
from sklearn.linear_model import LinearRegression as LinReg
from sklearn.linear_model import Lasso        
from sklearn.linear_model import Ridge        
from sklearn.linear_model import ElasticNet

# %%
# se inician los modelos

linreg=LinReg()
lasso=Lasso()
ridge=Ridge()
elastic=ElasticNet()

# %%
# Entrenamiento. Regresiones lineales

linreg.fit(X_train, y_train)
lasso.fit(X_train, y_train)
ridge.fit(X_train, y_train)
elastic.fit(X_train, y_train)
# Out:
# ElasticNet()

# %%
# Predicción

linreg.predict(X_test)[:2]
# Out:
# array([154494.21629965, 143532.5014713 ])

# %%
lasso.predict(X_test)[:2]
# Out:
# array([154447.39907088, 143560.51336471])

# %%
ridge.predict(X_test)[:2]
# Out:
# array([151956.47595915, 143994.87372855])

# %%
elastic.predict(X_test)[:2]
# Out:
# array([129568.74282639, 127456.94025876])

# %%
# Evaluación.

from sklearn.metrics import mean_squared_error as mse  # error cuadratico medio

#y_pred=linreg.predict(X_test)
#mse(y_test, y_pred, squared=False)

# %%
#y_pred=lasso.predict(X_test)
#mse(y_test, y_pred, squared=False)

# %%
y_pred=ridge.predict(X_test)

mse(y_test, y_pred, squared=False)
# Out:
# 34748.590758848535

# %%
#y_pred=elastic.predict(X_test)

#mse(y_test, y_pred, squared=False)

# %%
len(test_lim)
# Out:
# 107

# %%
y_pred=ridge.predict(test_lim)
y_pred
# Out:
# array([123244.55192796, 137984.78317286, 137984.78317286,  39930.06784638,
#         34245.75258183,  67460.70039626, 129556.7777282 ,  47570.96796626,
#         65636.75613844, 181587.86162437,  61309.68115395, 181548.32403385,
#         66536.91534244,  14716.30077118,  66445.02129138,  46008.41734868,
#        119241.8499446 , 151956.47595915,  56662.4908378 ,  68742.11964675,
#         37714.05363736,  71407.78954291, 134144.81898133, 161599.03833441,
#          3370.75552139,   6426.9423556 , 101404.33791171, 169610.07003819,
#         77330.57076687, 162188.36675036, 124566.26600639, 134542.74592143,
#        122845.90727638,  57601.23389591,  23146.74019025,  81216.53508248,
#        161599.03833441,  29199.72319467,  59086.68711242, 175315.51823891,
#         25131.57644938,  30803.7153304 , 131712.4397874 , 180941.89125859,
#        112736.15913211, 235106.42995624, 126908.17483425,  59086.68711242,
# ...

# %%
index_lst = [i for i in range(107)]
results = pd.DataFrame({"id" : index_lst, "salary_in_usd" : y_pred})
results.to_csv("results3.csv", index=False)
